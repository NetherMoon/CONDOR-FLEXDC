# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pickle
import numpy as np
import random

# %%
dict_location = '../../data/python_data/'
jobtype_filehandler = open(dict_location + 'job_dictionary.dict', 'rb') 
jobtype_dict = pickle.load(jobtype_filehandler)

# %%
average = np.array([0.,0.,0.,0.,0.,0.])
for key in jobtype_dict:
    average += np.array(jobtype_dict[key])
print(np.array(average)/len(jobtype_dict))
# Out:
# [252.60714286 346.34821429 252.93928571 297.96428571   1.26071429
#    2.71428571]

# %%
array_1 = np.array([1,2,3,4])
array_2 = np.array([4,5,6,7])

print(array_1/array_2)
# Out:
# [0.25       0.4        0.5        0.57142857]
